# %% [markdown]
# # GCCN prediction for perovskites

# %%
from tf_chpvk_pv.modeling.GCCN_Predict import run_prediction

run_prediction()
# Out:
# 2026-02-17 07:48:49.914 | INFO     | tf_chpvk_pv.config:<module>:11 - PROJ_ROOT path is: /home/dagar/TF-ChPVK-PV
# loading data...completed 0.035219430923461914 sec
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_000.pth.tar
# /home/dagar/TF-ChPVK-PV/tf_chpvk_pv/modeling/GCCN_Predict.py:116: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(p))
# Pred : [0][0/1]	Time 1.862 (1.862)
# Pred  end: [0]	Time 1.862
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_001.pth.tar
# Pred : [1][0/1]	Time 0.034 (0.034)
# Pred  end: [1]	Time 0.034
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_002.pth.tar
# Pred : [2][0/1]	Time 0.012 (0.012)
# Pred  end: [2]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_003.pth.tar
# Pred : [3][0/1]	Time 0.019 (0.019)
# Pred  end: [3]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_004.pth.tar
# Pred : [4][0/1]	Time 0.013 (0.013)
# Pred  end: [4]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_005.pth.tar
# Pred : [5][0/1]	Time 0.013 (0.013)
# Pred  end: [5]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_006.pth.tar
# Pred : [6][0/1]	Time 0.011 (0.011)
# Pred  end: [6]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_007.pth.tar
# Pred : [7][0/1]	Time 0.014 (0.014)
# Pred  end: [7]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_008.pth.tar
# Pred : [8][0/1]	Time 0.011 (0.011)
# Pred  end: [8]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_009.pth.tar
# Pred : [9][0/1]	Time 0.025 (0.025)
# Pred  end: [9]	Time 0.025
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_010.pth.tar
# Pred : [10][0/1]	Time 0.011 (0.011)
# Pred  end: [10]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_011.pth.tar
# Pred : [11][0/1]	Time 0.015 (0.015)
# Pred  end: [11]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_012.pth.tar
# Pred : [12][0/1]	Time 0.018 (0.018)
# Pred  end: [12]	Time 0.018
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_013.pth.tar
# Pred : [13][0/1]	Time 0.012 (0.012)
# Pred  end: [13]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_014.pth.tar
# Pred : [14][0/1]	Time 0.014 (0.014)
# Pred  end: [14]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_015.pth.tar
# Pred : [15][0/1]	Time 0.016 (0.016)
# Pred  end: [15]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_016.pth.tar
# Pred : [16][0/1]	Time 0.014 (0.014)
# Pred  end: [16]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_017.pth.tar
# Pred : [17][0/1]	Time 0.014 (0.014)
# Pred  end: [17]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_018.pth.tar
# Pred : [18][0/1]	Time 0.016 (0.016)
# Pred  end: [18]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_019.pth.tar
# Pred : [19][0/1]	Time 0.018 (0.018)
# Pred  end: [19]	Time 0.018
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_020.pth.tar
# Pred : [20][0/1]	Time 0.013 (0.013)
# Pred  end: [20]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_021.pth.tar
# Pred : [21][0/1]	Time 0.014 (0.014)
# Pred  end: [21]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_022.pth.tar
# Pred : [22][0/1]	Time 0.015 (0.015)
# Pred  end: [22]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_023.pth.tar
# Pred : [23][0/1]	Time 0.011 (0.011)
# Pred  end: [23]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_024.pth.tar
# Pred : [24][0/1]	Time 0.016 (0.016)
# Pred  end: [24]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_025.pth.tar
# Pred : [25][0/1]	Time 0.012 (0.012)
# Pred  end: [25]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_026.pth.tar
# Pred : [26][0/1]	Time 0.013 (0.013)
# Pred  end: [26]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_027.pth.tar
# Pred : [27][0/1]	Time 0.012 (0.012)
# Pred  end: [27]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_028.pth.tar
# Pred : [28][0/1]	Time 0.013 (0.013)
# Pred  end: [28]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_029.pth.tar
# Pred : [29][0/1]	Time 0.019 (0.019)
# Pred  end: [29]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_030.pth.tar
# Pred : [30][0/1]	Time 0.012 (0.012)
# Pred  end: [30]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_031.pth.tar
# Pred : [31][0/1]	Time 0.014 (0.014)
# Pred  end: [31]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_032.pth.tar
# Pred : [32][0/1]	Time 0.014 (0.014)
# Pred  end: [32]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_033.pth.tar
# Pred : [33][0/1]	Time 0.015 (0.015)
# Pred  end: [33]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_034.pth.tar
# Pred : [34][0/1]	Time 0.016 (0.016)
# Pred  end: [34]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_035.pth.tar
# Pred : [35][0/1]	Time 0.014 (0.014)
# Pred  end: [35]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_036.pth.tar
# Pred : [36][0/1]	Time 0.016 (0.016)
# Pred  end: [36]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_037.pth.tar
# Pred : [37][0/1]	Time 0.017 (0.017)
# Pred  end: [37]	Time 0.017
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_038.pth.tar
# Pred : [38][0/1]	Time 0.012 (0.012)
# Pred  end: [38]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_039.pth.tar
# Pred : [39][0/1]	Time 0.013 (0.013)
# Pred  end: [39]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_040.pth.tar
# Pred : [40][0/1]	Time 0.015 (0.015)
# Pred  end: [40]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_041.pth.tar
# Pred : [41][0/1]	Time 0.013 (0.013)
# Pred  end: [41]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_042.pth.tar
# Pred : [42][0/1]	Time 0.015 (0.015)
# Pred  end: [42]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_043.pth.tar
# Pred : [43][0/1]	Time 0.016 (0.016)
# Pred  end: [43]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_044.pth.tar
# Pred : [44][0/1]	Time 0.013 (0.013)
# Pred  end: [44]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_045.pth.tar
# Pred : [45][0/1]	Time 0.014 (0.014)
# Pred  end: [45]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_046.pth.tar
# Pred : [46][0/1]	Time 0.014 (0.014)
# Pred  end: [46]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_047.pth.tar
# Pred : [47][0/1]	Time 0.012 (0.012)
# Pred  end: [47]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_048.pth.tar
# Pred : [48][0/1]	Time 0.016 (0.016)
# Pred  end: [48]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_049.pth.tar
# Pred : [49][0/1]	Time 0.019 (0.019)
# Pred  end: [49]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_050.pth.tar
# Pred : [50][0/1]	Time 0.015 (0.015)
# Pred  end: [50]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_051.pth.tar
# Pred : [51][0/1]	Time 0.016 (0.016)
# Pred  end: [51]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_052.pth.tar
# Pred : [52][0/1]	Time 0.013 (0.013)
# Pred  end: [52]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_053.pth.tar
# Pred : [53][0/1]	Time 0.014 (0.014)
# Pred  end: [53]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_054.pth.tar
# Pred : [54][0/1]	Time 0.013 (0.013)
# Pred  end: [54]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_055.pth.tar
# Pred : [55][0/1]	Time 0.014 (0.014)
# Pred  end: [55]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_056.pth.tar
# Pred : [56][0/1]	Time 0.013 (0.013)
# Pred  end: [56]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_057.pth.tar
# Pred : [57][0/1]	Time 0.012 (0.012)
# Pred  end: [57]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_058.pth.tar
# Pred : [58][0/1]	Time 0.015 (0.015)
# Pred  end: [58]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_059.pth.tar
# Pred : [59][0/1]	Time 0.013 (0.013)
# Pred  end: [59]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_060.pth.tar
# Pred : [60][0/1]	Time 0.019 (0.019)
# Pred  end: [60]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_061.pth.tar
# Pred : [61][0/1]	Time 0.019 (0.019)
# Pred  end: [61]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_062.pth.tar
# Pred : [62][0/1]	Time 0.016 (0.016)
# Pred  end: [62]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_063.pth.tar
# Pred : [63][0/1]	Time 0.013 (0.013)
# Pred  end: [63]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_064.pth.tar
# Pred : [64][0/1]	Time 0.014 (0.014)
# Pred  end: [64]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_065.pth.tar
# Pred : [65][0/1]	Time 0.012 (0.012)
# Pred  end: [65]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_066.pth.tar
# Pred : [66][0/1]	Time 0.015 (0.015)
# Pred  end: [66]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_067.pth.tar
# Pred : [67][0/1]	Time 0.012 (0.012)
# Pred  end: [67]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_068.pth.tar
# Pred : [68][0/1]	Time 0.013 (0.013)
# Pred  end: [68]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_069.pth.tar
# Pred : [69][0/1]	Time 0.014 (0.014)
# Pred  end: [69]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_070.pth.tar
# Pred : [70][0/1]	Time 0.015 (0.015)
# Pred  end: [70]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_071.pth.tar
# Pred : [71][0/1]	Time 0.011 (0.011)
# Pred  end: [71]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_072.pth.tar
# Pred : [72][0/1]	Time 0.019 (0.019)
# Pred  end: [72]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_073.pth.tar
# Pred : [73][0/1]	Time 0.022 (0.022)
# Pred  end: [73]	Time 0.022
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_074.pth.tar
# Pred : [74][0/1]	Time 0.017 (0.017)
# Pred  end: [74]	Time 0.017
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_075.pth.tar
# Pred : [75][0/1]	Time 0.014 (0.014)
# Pred  end: [75]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_076.pth.tar
# Pred : [76][0/1]	Time 0.015 (0.015)
# Pred  end: [76]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_077.pth.tar
# Pred : [77][0/1]	Time 0.015 (0.015)
# Pred  end: [77]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_078.pth.tar
# Pred : [78][0/1]	Time 0.011 (0.011)
# Pred  end: [78]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_079.pth.tar
# Pred : [79][0/1]	Time 0.011 (0.011)
# Pred  end: [79]	Time 0.011
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_080.pth.tar
# Pred : [80][0/1]	Time 0.013 (0.013)
# Pred  end: [80]	Time 0.013
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_081.pth.tar
# Pred : [81][0/1]	Time 0.012 (0.012)
# Pred  end: [81]	Time 0.012
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_082.pth.tar
# Pred : [82][0/1]	Time 0.016 (0.016)
# Pred  end: [82]	Time 0.016
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_083.pth.tar
# Pred : [83][0/1]	Time 0.014 (0.014)
# Pred  end: [83]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_084.pth.tar
# Pred : [84][0/1]	Time 0.014 (0.014)
# Pred  end: [84]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_085.pth.tar
# Pred : [85][0/1]	Time 0.018 (0.018)
# Pred  end: [85]	Time 0.018
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_086.pth.tar
# Pred : [86][0/1]	Time 0.014 (0.014)
# Pred  end: [86]	Time 0.014
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_087.pth.tar
# Pred : [87][0/1]	Time 0.025 (0.025)
# Pred  end: [87]	Time 0.025
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_088.pth.tar
# Pred : [88][0/1]	Time 0.019 (0.019)
# Pred  end: [88]	Time 0.019
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_089.pth.tar
# Pred : [89][0/1]	Time 0.017 (0.017)
# Pred  end: [89]	Time 0.017
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_090.pth.tar
# Pred : [90][0/1]	Time 0.015 (0.015)
# Pred  end: [90]	Time 0.015
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_091.pth.tar
# Pred : [91][0/1]	Time 0.024 (0.024)
# Pred  end: [91]	Time 0.024
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_092.pth.tar
# Pred : [92][0/1]	Time 0.025 (0.025)
# Pred  end: [92]	Time 0.025
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_093.pth.tar
# Pred : [93][0/1]	Time 0.032 (0.032)
# Pred  end: [93]	Time 0.032
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_094.pth.tar
# Pred : [94][0/1]	Time 0.033 (0.033)
# Pred  end: [94]	Time 0.033
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_095.pth.tar
# Pred : [95][0/1]	Time 0.029 (0.029)
# Pred  end: [95]	Time 0.029
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_096.pth.tar
# Pred : [96][0/1]	Time 0.029 (0.029)
# Pred  end: [96]	Time 0.029
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_097.pth.tar
# Pred : [97][0/1]	Time 0.027 (0.027)
# Pred  end: [97]	Time 0.027
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_098.pth.tar
# Pred : [98][0/1]	Time 0.027 (0.027)
# Pred  end: [98]	Time 0.027
# Loading model /home/dagar/TF-ChPVK-PV/data/interim/weights/W_Perov_All_099.pth.tar
# Pred : [99][0/1]	Time 0.025 (0.025)
# Pred  end: [99]	Time 0.025

# %% [markdown]
# Now let's check the results

# %%
import pandas as pd
from pymatgen.core.composition import Composition
from tf_chpvk_pv.config import PROCESSED_DATA_DIR
from tf_chpvk_pv.plots import normalize_abx3


pred = pd.read_csv(PROCESSED_DATA_DIR / "prediction.csv")

df_crystal = pd.read_csv(PROCESSED_DATA_DIR / "results_CrystaLLM_with_HHI.csv")
df_sisso = pd.read_csv(PROCESSED_DATA_DIR / "results_SISSO_with_bandgap.csv")

df_sisso.rename(columns={"formula": "material"}, inplace=True)

df_sisso["norm_formula"] = df_sisso["material"].apply(normalize_abx3)
df_crystal["norm_formula"] = df_crystal["material"].apply(normalize_abx3)

df_crystal_sisso = df_sisso[df_sisso['norm_formula'].isin(df_crystal['norm_formula'])].copy()
df_crystal_sisso['pymatgen_formula'] = df_crystal_sisso['material'].apply(lambda x: Composition(x).formula)

pred['Composition'] = pred['id'].apply(lambda x: x.replace("_1", "")).apply(Composition)
pred['pymatgen_formula'] = pred['Composition'].apply(lambda x: x.formula)

predsort_values = pred.sort_values(by='CL score', ascending=False)
predsort_values.head(10)
# Out:
#           id  CL score  CL score std  Composition pymatgen_formula
# 6   BaZrS3_1  0.990686      0.023706  (Ba, Zr, S)       Ba1 Zr1 S3
# 4    BaUS3_1  0.989047      0.016088   (Ba, U, S)        Ba1 U1 S3
# 18  EuScS3_1  0.987745      0.019361  (Eu, Sc, S)       Eu1 Sc1 S3
# 2   BaHfS3_1  0.987208      0.025012  (Ba, Hf, S)       Ba1 Hf1 S3
# 14  DyScS3_1  0.984986      0.016760  (Dy, Sc, S)       Dy1 Sc1 S3
# 10  CeScS3_1  0.982454      0.030949  (Ce, Sc, S)       Ce1 Sc1 S3
# 23  EuZrS3_1  0.981398      0.030479  (Eu, Zr, S)       Eu1 Zr1 S3
# 24  GdScS3_1  0.980566      0.042843  (Gd, Sc, S)       Gd1 Sc1 S3
# 41  SrSnS3_1  0.980511      0.035993  (Sr, Sn, S)       Sr1 Sn1 S3
# 28  LaScS3_1  0.975184      0.081812  (La, Sc, S)       La1 Sc1 S3

# %%
df_crystal_sisso.columns
# Out:
# Index(['material', 'A', 'B', 'X', 'nA', 'nB', 'nX', 'chi_A', 'chi_B', 'chi_X',
#        'chi_diff', 'rX', 'rA', 'rB', 'delta_chi_AX', 'delta_chi_BX',
#        'delta_chi_AO', 'delta_chi_BO', 'rA_rB_ratio', 'rB_rX_ratio',
#        'rA_rX_ratio', 'chi_AX_ratio', 'chi_BX_ratio', 'HOMO_A', 'HOMO_B',
#        'HOMO_X', 'LUMO_A', 'LUMO_B', 'LUMO_X', 'EA_A', 'EA_B', 'EA_X', 'IP_A',
#        'IP_B', 'IP_X', 'rS_A', 'rS_B', 'rS_X', 'rP_A', 'rP_B', 'rP_X', 'rD_A',
#        'rD_B', 'rD_X', 't_sisso', 't', 'tau', 't_jess', 'bandgap',
#        'bandgap_sigma', 'norm_formula', 'pymatgen_formula'],
#       dtype='object')

# %%
final_pred = predsort_values.merge(df_crystal_sisso, on='pymatgen_formula', how='left')
final_pred.head(10)
# Out:
#          id  CL score  CL score std  Composition pymatgen_formula material  \
# 0  BaZrS3_1  0.990686      0.023706  (Ba, Zr, S)       Ba1 Zr1 S3   BaZrS3
# 1   BaUS3_1  0.989047      0.016088   (Ba, U, S)        Ba1 U1 S3    BaUS3
# 2  EuScS3_1  0.987745      0.019361  (Eu, Sc, S)       Eu1 Sc1 S3   EuScS3
# 3  BaHfS3_1  0.987208      0.025012  (Ba, Hf, S)       Ba1 Hf1 S3   BaHfS3
# 4  DyScS3_1  0.984986      0.016760  (Dy, Sc, S)       Dy1 Sc1 S3   DyScS3
# 5  CeScS3_1  0.982454      0.030949  (Ce, Sc, S)       Ce1 Sc1 S3   CeScS3
# 6  EuZrS3_1  0.981398      0.030479  (Eu, Zr, S)       Eu1 Zr1 S3   EuZrS3
# 7  GdScS3_1  0.980566      0.042843  (Gd, Sc, S)       Gd1 Sc1 S3   GdScS3
# 8  SrSnS3_1  0.980511      0.035993  (Sr, Sn, S)       Sr1 Sn1 S3   SrSnS3
# 9  LaScS3_1  0.975184      0.081812  (La, Sc, S)       La1 Sc1 S3   LaScS3
#
#     A   B  X   nA  ...    rD_A    rD_B    rD_X   t_sisso         t       tau  \
# 0  Ba  Zr  S  2.0  ...  131.01   84.44  273.21  0.819697  0.938430  3.892763
# 1  Ba   U  S  2.0  ...  131.01  131.23  273.21  0.667229  0.892006  4.120009
# 2  Eu  Sc  S  3.0  ...  114.02   58.09  273.21  0.817190  0.908021  2.035359
# 3  Ba  Hf  S  2.0  ...  131.01   89.51  273.21  0.819697  0.938430  3.892763
# 4  Dy  Sc  S  3.0  ...  111.98   58.09  273.21  0.809484  0.858445  2.903018
# 5  Ce  Sc  S  3.0  ...  118.68   58.09  273.21  0.821182  0.898106  2.163268
# 6  Eu  Zr  S  2.0  ...  114.02   84.44  273.21  0.840446  0.914772  4.036183
# 7  Gd  Sc  S  3.0  ...  111.28   58.09  273.21  0.820321  0.876710  2.508560
# 8  Sr  Sn  S  2.0  ...  111.21   46.94  273.21  0.821503  0.921860  3.974182
# 9  La  Sc  S  3.0  ...  119.73   58.09  273.21  0.818168  0.871492  2.610363
#
#      t_jess   bandgap  bandgap_sigma  norm_formula
# 0  1.049835  1.789960       0.157152        BaZrS3
# 1  1.014847  2.531824       0.260006         BaUS3
# 2  0.953741  1.728760       0.254795        EuScS3
# 3  1.039806  2.026456       0.207781        BaHfS3
# 4  0.896607  2.046099       0.216236        DyScS3
# 5  0.963598  1.794310       0.190333        CeScS3
# 6  0.951298  1.798262       0.214813        EuZrS3
# 7  0.920854  1.930928       0.188730        GdScS3
# 8  1.440533  2.090290       0.525292        SnSrS3
# 9  0.939751  1.921158       0.272241        LaScS3
#
# [10 rows x 56 columns]

# %% [markdown]
# Here we plot the new derived CL score (Crystal-likeness score) vs the radii of the cations to evaluate any kind of correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context("talk")

sns.scatterplot(data=final_pred, y='CL score', x='rA')

print(final_pred[['rA', 'CL score']].corr())
# Out:
#                 rA  CL score
# rA        1.000000  0.303425
# CL score  0.303425  1.000000

# %%
sns.scatterplot(data=final_pred, y='CL score', x='rB')

print(final_pred[['rB', 'CL score']].corr())
# Out:
#                 rB  CL score
# rB        1.000000 -0.147898
# CL score -0.147898  1.000000

# %% [markdown]
# Save the final data with the proper composition for the stable perovskite-type structures

# %%
final_pred[['Composition', 'CL score', 'CL score std']].to_csv(PROCESSED_DATA_DIR / "final_CL_scores.csv", index=False)

# %% [markdown]
# # Trial with thermodynamics data from MaterialsProject

# %% [markdown]
# Definition of the main function to look up for the system (A-B-X) based on the composition ABX$_3$ withouth considering oxygen

# %%
from tf_chpvk_pv.synthesis_planning.synthesis_pathways import SynthesisPathways
from tf_chpvk_pv.synthesis_planning.interfacial_pdplotter import InterReactions, Inter_PDPlotter

from pymatgen.analysis.reaction_calculator import ComputedReaction
from pymatgen.analysis.phase_diagram import CompoundPhaseDiagram

def get_reaction_from_string(target, to_show = True):

    # get the optimal synthesis recipe for a target material
    sp = SynthesisPathways(target,
                        exclude_reactants = ["O2"],
                        selected_reactions_to_csv = True)

    # display the selected reactions
    for reaction in sp.selected_reactions:
        reaction.display()

    # Visualize interfacial reaction compound phase diagram for the optimal reaction
    if len(sp.selected_reactions) > 0:
        reaction = sp.selected_reactions[0]
        interfacial_reactions = InterReactions(reaction)
        Inter_PDPlotter(
            interfacial_reactions,
            emphasize_entries = [reaction.target]
        ).show(to_show=to_show)
# Out:
# 2026-02-16 12:32:29.386 | INFO     | tf_chpvk_pv.config:<module>:11 - PROJ_ROOT path is: /home/dagar/TF-ChPVK-PV
# /home/dagar/TF-ChPVK-PV/tf_chpvk_pv/synthesis_planning/materials_entries.py:15: UserWarning: MP_API_KEY environment variable not set. Materials Project API calls will fail. Set it in a .env file or export MP_API_KEY=your_key
#   from tf_chpvk_pv.synthesis_planning import settings

# %% [markdown]
# CrystaLLM predicted stable perovkiste-type compositions

# %%
#CrystaLLM predictions processing

import pandas as pd
from tf_chpvk_pv.config import CRYSTALLM_DATA_DIR, PROCESSED_DATA_DIR


df_compositions = pd.read_csv(CRYSTALLM_DATA_DIR / 'results CrystaLLM.csv')
df_compositions.rename(columns={'material': 'formula'}, inplace=True)
df_compositions.set_index('formula', inplace=True)


for formula in df_compositions.index:
    try:
        get_reaction_from_string(formula, False)
    except Exception as e:
        print(f"Error processing {formula}: {e}")
        continue
# Out:
# loading from cache. stable entries S-Tb-Zn
# all possible pairwise reactions: 2
#
# target: TbZnS3
# reactants: ['ZnS', 'TbS2']
# reaction energy: -0.00020000000000663923
# inverse hull energy: -0.0002000000000066393
# reaction: ZnS + TbS2 -> TbZnS3
# competing phases: []
#
#
# loading from cache. stable entries Se-Sr-U
# all possible pairwise reactions: 2
#
# target: SrUSe3
# reactants: ['USe2', 'SrSe']
# reaction energy: -0.00020000000009048335
# inverse hull energy: -0.00020000000009012808
# reaction: USe2 + SrSe -> SrUSe3
# competing phases: []
#
#
# loading from cache. stable entries Ce-Se-U
# all possible pairwise reactions: 5
# No valid reactions found for CeUSe3. with the current reactions: [0.5 Ce2Se3 + 0.5 U2Se3 -> CeUSe3, CeSe + USe2 -> CeUSe3, Ce + USe3 -> CeUSe3, USe + CeSe2 -> CeUSe3, 0.5 USe + 0.5 Ce2USe5 -> CeUSe3]
# loading from cache. stable entries Al-Se-Sn
# all possible pairwise reactions: 0
# No valid reactions found for AlSnSe3. with the current reactions: []
# loading from cache. stable entries Eu-S-Tb
# all possible pairwise reactions: 2
# No valid reactions found for TbEuS3. with the current reactions: [EuS2 + TbS -> TbEuS3, TbS2 + EuS -> TbEuS3]
# loading from cache. stable entries Eu-Se-Yb
# Error processing YbEuSe3: Yb1 Eu1 Se3 has elements not in the phase diagram Eu, Se
# loading from cache. stable entries Lu-S-Sm
# all possible pairwise reactions: 2
#
# target: SmLuS3
# reactants: ['SmS2', 'LuS']
# reaction energy: -0.26603618624999825
# inverse hull energy: -0.09361626474996854
# reaction: SmS2 + LuS -> SmLuS3
# competing phases: [['Sm10S19', 'Lu2S3'], ['Sm2S3', 'Lu2S3'], ['Lu2S3', 'SmS'], ['Lu3S4', 'SmS']]
#
# target: SmLuS3
# reactants: ['Lu2S3', 'Sm2S3']
# reaction energy: -0.00019999999997253318
# inverse hull energy: -0.00019999999997200035
# reaction: 0.5 Lu2S3 + 0.5 Sm2S3 -> SmLuS3
# competing phases: []
#
#
# loading from cache. stable entries Pr-Se-U
# all possible pairwise reactions: 5
# No valid reactions found for PrUSe3. with the current reactions: [PrSe2 + USe -> PrUSe3, USe2 + PrSe -> PrUSe3, USe3 + Pr -> PrUSe3, 0.5 Pr2Se3 + 0.5 U2Se3 -> PrUSe3, 0.5 Pr2USe5 + 0.5 USe -> PrUSe3]
# loading from cache. stable entries Ba-S-U
# all possible pairwise reactions: 6
#
# target: BaUS3
# reactants: ['BaS2', 'US']
# reaction energy: -0.3209084235000041
# inverse hull energy: -0.11134184910000222
# reaction: BaS2 + US -> BaUS3
# competing phases: [['Ba2US6', 'BaS'], ['U2S3', 'BaS']]
#
# target: BaUS3
# reactants: ['BaS', 'US2']
# reaction energy: -0.0673389274999876
# inverse hull energy: -0.02090515550014782
# reaction: BaS + US2 -> BaUS3
# competing phases: ['BaU2S5']
#
# target: BaUS3
# reactants: ['BaS', 'BaU2S5']
# reaction energy: -0.02090515550000165
# inverse hull energy: -0.020905155500003048
# reaction: 0.5 BaS + 0.5 BaU2S5 -> BaUS3
# competing phases: []
#
#
# loading from cache. stable entries La-S-Tb
# all possible pairwise reactions: 3
#
# target: LaTbS3
# reactants: ['LaS2', 'TbS']
# reaction energy: -0.21307448125003817
# inverse hull energy: -0.03678303114293158
# reaction: LaS2 + TbS -> LaTbS3
# competing phases: [['La10S19', 'Tb2S3'], ['La2S3', 'Tb2S3'], ['La2S3', 'Tb5S7'], ['Tb5S7', 'LaS']]
#
# target: LaTbS3
# reactants: ['TbS2', 'LaS']
# reaction energy: -0.2319133867500426
# inverse hull energy: -0.026691160482759102
# reaction: TbS2 + LaS -> LaTbS3
# competing phases: [['LaS2', 'Tb2S3'], ['La10S19', 'Tb2S3'], ['La2S3', 'Tb2S3'], ['La2S3', 'Tb5S7']]
#
# target: LaTbS3
# reactants: ['La2S3', 'Tb2S3']
# reaction energy: -0.0002000000000393242
# inverse hull energy: -0.0002000000000395019
# reaction: 0.5 La2S3 + 0.5 Tb2S3 -> LaTbS3
# competing phases: []
#
#
# loading from cache. stable entries Ba-Pr-S
# all possible pairwise reactions: 3
# No valid reactions found for BaPrS3. with the current reactions: [PrS + BaS2 -> BaPrS3, BaS + PrS2 -> BaPrS3, BaS3 + Pr -> BaPrS3]
# loading from cache. stable entries Eu-S-Sc
# all possible pairwise reactions: 1
# No valid reactions found for EuScS3. with the current reactions: [EuS2 + ScS -> EuScS3]
# loading from cache. stable entries Ba-Se-U
# all possible pairwise reactions: 7
#
# target: BaUSe3
# reactants: ['USe', 'BaSe2']
# reaction energy: -0.30184914235714033
# inverse hull energy: -0.05078818585714284
# reaction: USe + BaSe2 -> BaUSe3
# competing phases: [['U2Se3', 'BaSe'], ['Ba4USe6', 'U2Se3'], ['BaU2Se5', 'Ba4USe6'], ['USe3', 'Ba4USe6']]
#
# target: BaUSe3
# reactants: ['Ba4USe6', 'BaU2Se5']
# reaction energy: -0.00020000000002511363
# inverse hull energy: -0.00020000000002440288
# reaction: 0.1429 Ba4USe6 + 0.4286 BaU2Se5 -> BaUSe3
# competing phases: []
#
#
# loading from cache. stable entries Ca-Se-U
# all possible pairwise reactions: 2
#
# target: CaUSe3
# reactants: ['CaSe', 'USe2']
# reaction energy: -0.00019999999999811287
# inverse hull energy: -0.00019999999999686935
# reaction: CaSe + USe2 -> CaUSe3
# competing phases: []
#
#
# loading from cache. stable entries Ce-S-Sc
# all possible pairwise reactions: 2
#
# target: CeScS3
# reactants: ['CeS2', 'ScS']
# reaction energy: -0.19431575699998663
# inverse hull energy: -0.09257641599998667
# reaction: CeS2 + ScS -> CeScS3
# competing phases: [['Sc2S3', 'CeS']]
#
# target: CeScS3
# reactants: ['Sc2S3', 'Ce2S3']
# reaction energy: -0.005039687750006312
# inverse hull energy: -0.005039687750007182
# reaction: 0.5 Sc2S3 + 0.5 Ce2S3 -> CeScS3
# competing phases: []
#
#
# loading from cache. stable entries Gd-S-Sc
# all possible pairwise reactions: 3
#
# target: GdScS3
# reactants: ['GdS2', 'ScS']
# reaction energy: -0.20901087583332725
# inverse hull energy: -0.04118121367158345
# reaction: GdS2 + ScS -> GdScS3
# competing phases: [['Gd10S19', 'Sc2S3'], ['Gd3ScS6', 'Sc2S3'], ['Gd3Sc2S7', 'Sc2S3']]
#
# target: GdScS3
# reactants: ['Sc2S3', 'Gd3ScS6']
# reaction energy: -0.00019999999999100715
# inverse hull energy: -0.0001999999999906521
# reaction: 0.3333 Sc2S3 + 0.3333 Gd3ScS6 -> GdScS3
# competing phases: []
#
#
# loading from cache. stable entries S-Sm-Zr
# all possible pairwise reactions: 4
# No valid reactions found for SmZrS3. with the current reactions: [0.5 Sm2ZrS5 + 0.5 ZrS -> SmZrS3, Sm + ZrS3 -> SmZrS3, ZrS + SmS2 -> SmZrS3, ZrS2 + SmS -> SmZrS3]
# loading from cache. stable entries In-S-U
# all possible pairwise reactions: 3
#
# target: UInS3
# reactants: ['U2S3', 'In2S3']
# reaction energy: -0.014956599375020113
# inverse hull energy: -0.006525375083338503
# reaction: 0.5 U2S3 + 0.5 In2S3 -> UInS3
# competing phases: [['U3S5', 'InS'], ['US2', 'InS']]
#
# target: UInS3
# reactants: ['InS', 'US2']
# reaction energy: -0.00020000000000237598
# inverse hull energy: -0.0002000000000030866
# reaction: InS + US2 -> UInS3
# competing phases: []
#
#
# loading from cache. stable entries Bi-S-U
# all possible pairwise reactions: 3
# No valid reactions found for UBiS3. with the current reactions: [BiS2 + US -> UBiS3, 0.5 U2S3 + 0.5 Bi2S3 -> UBiS3, US3 + Bi -> UBiS3]
# loading from cache. stable entries S-Sc-U
# all possible pairwise reactions: 4
#
# target: ScUS3
# reactants: ['ScS', 'US2']
# reaction energy: -0.12472128900007395
# inverse hull energy: -0.023477991750161742
# reaction: ScS + US2 -> ScUS3
# competing phases: [['Sc2S3', 'US'], ['Sc2S3', 'U2S3'], ['U3S5', 'Sc2S3'], 'ScU8S17']
#
# target: ScUS3
# reactants: ['ScS', 'ScU8S17']
# reaction energy: -0.10111675999994808
# inverse hull energy: -0.023477991749976113
# reaction: 0.875 ScS + 0.125 ScU8S17 -> ScUS3
# competing phases: [['Sc2S3', 'US'], ['Sc2S3', 'U2S3'], ['U3S5', 'Sc2S3']]
#
# target: ScUS3
# reactants: ['Sc2S3', 'U2S3']
# reaction energy: -0.00019999999999527056
# inverse hull energy: -0.0001999999999942048
# reaction: 0.5 Sc2S3 + 0.5 U2S3 -> ScUS3
# competing phases: []
#
#
# loading from cache. stable entries Pr-S-Sr
# all possible pairwise reactions: 2
#
# target: SrPrS3
# reactants: ['SrS', 'PrS2']
# reaction energy: -0.0002000000000187186
# inverse hull energy: -0.0002000000000190738
# reaction: SrS + PrS2 -> SrPrS3
# competing phases: []
#
#
# loading from cache. stable entries Cd-Ce-S
# all possible pairwise reactions: 2
#
# target: CeCdS3
# reactants: ['CeS2', 'CdS']
# reaction energy: -0.00020000000000379713
# inverse hull energy: -0.00020000000000397478
# reaction: CeS2 + CdS -> CeCdS3
# competing phases: []
#
#
# loading from cache. stable entries Pr-S-Sc
# all possible pairwise reactions: 2
#
# target: PrScS3
# reactants: ['ScS', 'PrS2']
# reaction energy: -0.211742943000037
# inverse hull energy: -0.21174294300003726
# reaction: ScS + PrS2 -> PrScS3
# competing phases: []
#
# target: PrScS3
# reactants: ['Sc2S3', 'Pr2S3']
# reaction energy: -0.01792582675000751
# inverse hull energy: -0.01792582675000709
# reaction: 0.5 Sc2S3 + 0.5 Pr2S3 -> PrScS3
# competing phases: []
#
#
# loading from cache. stable entries Cu-Hf-S
# all possible pairwise reactions: 3
#
# target: HfCuS3
# reactants: ['HfS3', 'Cu']
# reaction energy: -0.06690992266666906
# inverse hull energy: -0.025916790880956775
# reaction: HfS3 + Cu -> HfCuS3
# competing phases: [['CuS', 'HfS2'], ['Cu7S4', 'HfS2']]
#
# target: HfCuS3
# reactants: ['HfS2', 'CuS']
# reaction energy: -0.00019999999999953388
# inverse hull energy: -0.00019999999999953388
# reaction: HfS2 + CuS -> HfCuS3
# competing phases: []
#
#
# loading from cache. stable entries La-Se-Tb
# all possible pairwise reactions: 2
#
# target: LaTbSe3
# reactants: ['TbSe', 'LaSe2']
# reaction energy: -0.19096069612500266
# inverse hull energy: -0.07698100943055763
# reaction: TbSe + LaSe2 -> LaTbSe3
# competing phases: [['Tb2Se3', 'LaSe'], ['La2Se3', 'Tb2Se3'], ['La10Se19', 'Tb2Se3'], ['La10Se19', 'Tb8Se15']]
#
# target: LaTbSe3
# reactants: ['La2Se3', 'Tb2Se3']
# reaction energy: -0.00019999999999456003
# inverse hull energy: -0.0001999999999942048
# reaction: 0.5 La2Se3 + 0.5 Tb2Se3 -> LaTbSe3
# competing phases: []
#
#
# loading from cache. stable entries Eu-Se-U
# all possible pairwise reactions: 3
#
# target: EuUSe3
# reactants: ['EuSe', 'USe2']
# reaction energy: -0.00020000000000095503
# inverse hull energy: -0.00019999999999775753
# reaction: EuSe + USe2 -> EuUSe3
# competing phases: []
#
#
# loading from cache. stable entries Eu-S-Tm
# all possible pairwise reactions: 1
# No valid reactions found for EuTmS3. with the current reactions: [TmS + EuS2 -> EuTmS3]
# loading from cache. stable entries Eu-S-Yb
# Error processing YbEuS3: Yb1 Eu1 S3 has elements not in the phase diagram Eu, S
# loading from cache. stable entries Dy-S-Zr
# all possible pairwise reactions: 4
# No valid reactions found for DyZrS3. with the current reactions: [ZrS + DyS2 -> DyZrS3, 0.5 ZrS + 0.5 Dy2ZrS5 -> DyZrS3, Dy + ZrS3 -> DyZrS3, DyS + ZrS2 -> DyZrS3]
# loading from cache. stable entries In-Se-U
# all possible pairwise reactions: 3
#
# target: UInSe3
# reactants: ['USe2', 'InSe']
# reaction energy: -0.00019999999999029683
# inverse hull energy: -0.00019999999998976392
# reaction: USe2 + InSe -> UInSe3
# competing phases: []
#
#
# loading from cache. stable entries Dy-Eu-S
# all possible pairwise reactions: 3
#
# target: EuDyS3
# reactants: ['EuS2', 'Eu(DyS2)2']
# reaction energy: -0.00019999999996116454
# inverse hull energy: -0.0001999999999613422
# reaction: 0.5 EuS2 + 0.5 Eu(DyS2)2 -> EuDyS3
# competing phases: []
#
#
# loading from cache. stable entries La-S-Zr
# all possible pairwise reactions: 4
# No valid reactions found for LaZrS3. with the current reactions: [ZrS + LaS2 -> LaZrS3, 0.5 ZrS + 0.5 La2ZrS5 -> LaZrS3, LaS + ZrS2 -> LaZrS3, La + ZrS3 -> LaZrS3]
# loading from cache. stable entries S-Sc-Sm
# all possible pairwise reactions: 2
#
# target: SmScS3
# reactants: ['ScS', 'SmS2']
# reaction energy: -0.20758151150003695
# inverse hull energy: -0.16405940025000998
# reaction: ScS + SmS2 -> SmScS3
# competing phases: [['Sm10S19', 'Sc2S3']]
#
# target: SmScS3
# reactants: ['Sc2S3', 'Sm2S3']
# reaction energy: -0.007425410500007982
# inverse hull energy: -0.00742541050000689
# reaction: 0.5 Sc2S3 + 0.5 Sm2S3 -> SmScS3
# competing phases: []
#
#
# loading from cache. stable entries Ba-Hf-S
# all possible pairwise reactions: 5
#
# target: BaHfS3
# reactants: ['BaS2', 'HfS']
# reaction energy: -0.3849322025000077
# inverse hull energy: -0.38493220250000704
# reaction: BaS2 + HfS -> BaHfS3
# competing phases: []
#
# target: BaHfS3
# reactants: ['HfS2', 'BaS']
# reaction energy: -0.06091738250000134
# inverse hull energy: -0.020429242499999667
# reaction: HfS2 + BaS -> BaHfS3
# competing phases: ['Ba2HfS4']
#
# target: BaHfS3
# reactants: ['HfS2', 'Ba2HfS4']
# reaction energy: -0.02042924249993377
# inverse hull energy: -0.020429242499932165
# reaction: 0.5 HfS2 + 0.5 Ba2HfS4 -> BaHfS3
# competing phases: []
#
#
# loading from cache. stable entries Cu-Hf-Se
# all possible pairwise reactions: 2
#
# target: HfCuSe3
# reactants: ['CuSe', 'HfSe2']
# reaction energy: -0.00019999999998532295
# inverse hull energy: -0.0001999999999862112
# reaction: CuSe + HfSe2 -> HfCuSe3
# competing phases: []
#
#
# loading from cache. stable entries Ce-S-U
# all possible pairwise reactions: 5
#
# target: CeUS3
# reactants: ['US', 'Ce2US5']
# reaction energy: -0.016570296000072926
# inverse hull energy: -0.016570296000073093
# reaction: 0.5 US + 0.5 Ce2US5 -> CeUS3
# competing phases: [['Ce2S3', 'U2S3']]
#
# target: CeUS3
# reactants: ['U2S3', 'Ce2S3']
# reaction energy: -0.00019999999997821752
# inverse hull energy: -0.0001999999999782176
# reaction: 0.5 U2S3 + 0.5 Ce2S3 -> CeUS3
# competing phases: []
#
#
# loading from cache. stable entries Dy-S-Sc
# all possible pairwise reactions: 2
#
# target: DyScS3
# reactants: ['ScS', 'DyS2']
# reaction energy: -0.24732852874999472
# inverse hull energy: -0.05389809237500032
# reaction: ScS + DyS2 -> DyScS3
# competing phases: [['Dy3Sc2S7', 'Sc2S3'], ['Dy2S3', 'Sc2S3']]
#
# target: DyScS3
# reactants: ['Sc2S3', 'Dy2S3']
# reaction energy: -0.0001999999999796386
# inverse hull energy: -0.00019999999997910578
# reaction: 0.5 Sc2S3 + 0.5 Dy2S3 -> DyScS3
# competing phases: []
#
#
# loading from cache. stable entries Ba-Ce-S
# all possible pairwise reactions: 3
#
# target: BaCeS3
# reactants: ['BaS', 'CeS2']
# reaction energy: -0.00020000000001161317
# inverse hull energy: -0.00020000000001196838
# reaction: BaS + CeS2 -> BaCeS3
# competing phases: []
#
#
# loading from cache. stable entries Eu-S-U
# all possible pairwise reactions: 4
#
# target: EuUS3
# reactants: ['EuS2', 'US']
# reaction energy: -0.2986181750000029
# inverse hull energy: -0.024162808499990973
# reaction: EuS2 + US -> EuUS3
# competing phases: [['Eu3S4', 'US3'], ['US3', 'EuS'], ['US2', 'EuS'], ['U3S5', 'EuS'], ['U2S3', 'EuS']]
#
# target: EuUS3
# reactants: ['U3S5', 'Eu3S4']
# reaction energy: -0.046560691999997045
# inverse hull energy: -0.024162808499985644
# reaction: 0.3333 U3S5 + 0.3333 Eu3S4 -> EuUS3
# competing phases: [['US2', 'EuS'], ['US3', 'EuS']]
#
# target: EuUS3
# reactants: ['EuS', 'US2']
# reaction energy: -0.0002000000000037972
# inverse hull energy: -0.0002000000000030866
# reaction: EuS + US2 -> EuUS3
# competing phases: []
#
#
# loading from cache. stable entries Eu-S-Zr
# all possible pairwise reactions: 3
#
# target: EuZrS3
# reactants: ['ZrS', 'EuS2']
# reaction energy: -0.3765158570000049
# inverse hull energy: -0.02900069138633654
# reaction: ZrS + EuS2 -> EuZrS3
# competing phases: [['Zr3S4', 'EuS'], ['Eu5(ZrS4)3', 'ZrS2'], ['Eu5(ZrS4)3', 'ZrS3'], ['Eu3S4', 'ZrS3']]
#
# target: EuZrS3
# reactants: ['ZrS2', 'EuS']
# reaction energy: -0.016404076000000597
# inverse hull energy: -0.0164040760000006
# reaction: ZrS2 + EuS -> EuZrS3
# competing phases: []
#
#
# loading from cache. stable entries S-Sc-Tb
# all possible pairwise reactions: 2
#
# target: TbScS3
# reactants: ['TbS2', 'ScS']
# reaction energy: -0.21009960349999232
# inverse hull energy: -0.047167852249986986
# reaction: TbS2 + ScS -> TbScS3
# competing phases: [['Tb2S3', 'Sc2S3'], ['Tb3Sc2S7', 'Sc2S3']]
#
# target: TbScS3
# reactants: ['Sc2S3', 'Tb2S3']
# reaction energy: -0.00019999999997821752
# inverse hull energy: -0.0001999999999782176
# reaction: 0.5 Sc2S3 + 0.5 Tb2S3 -> TbScS3
# competing phases: []
#
#
# loading from cache. stable entries Ce-S-Sr
# all possible pairwise reactions: 2
#
# target: SrCeS3
# reactants: ['SrS', 'CeS2']
# reaction energy: -0.0002000000000101921
# inverse hull energy: -0.00020000000001019203
# reaction: SrS + CeS2 -> SrCeS3
# competing phases: []
#
#
# loading from cache. stable entries Ca-Ce-S
# all possible pairwise reactions: 1
#
# target: CaCeS3
# reactants: ['CeS2', 'CaS']
# reaction energy: -0.00020000000000095497
# inverse hull energy: -0.00020000000000042206
# reaction: CeS2 + CaS -> CaCeS3
# competing phases: []
#
#
# loading from cache. stable entries Eu-Hf-S
# all possible pairwise reactions: 3
#
# target: EuHfS3
# reactants: ['EuS2', 'HfS']
# reaction energy: -0.37333723050000783
# inverse hull energy: -0.22328404216667863
# reaction: EuS2 + HfS -> EuHfS3
# competing phases: [['Eu3S4', 'HfS3']]
#
# target: EuHfS3
# reactants: ['EuS', 'HfS2']
# reaction energy: -0.004473731499989243
# inverse hull energy: -0.004473731499990308
# reaction: EuS + HfS2 -> EuHfS3
# competing phases: []
#
#
# loading from cache. stable entries S-Sn-Sr
# all possible pairwise reactions: 5
#
# target: SrSnS3
# reactants: ['Sr2SnS5', 'SnS']
# reaction energy: -0.02077697300001517
# inverse hull energy: -0.020776973000014465
# reaction: 0.5 Sr2SnS5 + 0.5 SnS -> SrSnS3
# competing phases: [['Sr2SnS4', 'SnS2']]
#
# target: SrSnS3
# reactants: ['SnS2', 'Sr2SnS4']
# reaction energy: -0.0002000000000052183
# inverse hull energy: -0.00020000000000486295
# reaction: 0.5 SnS2 + 0.5 Sr2SnS4 -> SrSnS3
# competing phases: []
#
#
# loading from cache. stable entries La-S-Sc
# all possible pairwise reactions: 2
#
# target: LaScS3
# reactants: ['ScS', 'LaS2']
# reaction energy: -0.21281249800001986
# inverse hull energy: -0.21281249800002033
# reaction: ScS + LaS2 -> LaScS3
# competing phases: []
#
# target: LaScS3
# reactants: ['Sc2S3', 'La2S3']
# reaction energy: -0.02508305425000836
# inverse hull energy: -0.025083054250008452
# reaction: 0.5 Sc2S3 + 0.5 La2S3 -> LaScS3
# competing phases: []
#
#
# loading from cache. stable entries S-Sr-U
# all possible pairwise reactions: 4
#
# target: SrUS3
# reactants: ['SrU2S5', 'SrS']
# reaction energy: -0.0002000000000052182
# inverse hull energy: -0.00020000000000575113
# reaction: 0.5 SrU2S5 + 0.5 SrS -> SrUS3
# competing phases: []
#
#
# loading from cache. stable entries Cu-Se-Zr
# all possible pairwise reactions: 3
# No valid reactions found for ZrCuSe3. with the current reactions: [CuSe + ZrSe2 -> ZrCuSe3, ZrSe + CuSe2 -> ZrCuSe3, ZrSe3 + Cu -> ZrCuSe3]
# loading from cache. stable entries Se-Sm-U
# all possible pairwise reactions: 3
#
# target: SmUSe3
# reactants: ['SmSe', 'USe2']
# reaction energy: -0.12647481064996105
# inverse hull energy: -0.03261866938888858
# reaction: SmSe + USe2 -> SmUSe3
# competing phases: [['Sm2Se3', 'U'], ['USe', 'Sm2Se3'], ['Sm2Se3', 'U2Se3'], ['Sm2Se3', 'U11Se20']]
#
# target: SmUSe3
# reactants: ['U2Se3', 'Sm2Se3']
# reaction energy: -0.0001999999999810597
# inverse hull energy: -0.00019999999997999396
# reaction: 0.5 U2Se3 + 0.5 Sm2Se3 -> SmUSe3
# competing phases: []
#
#
# loading from cache. stable entries Ba-S-Zr
# all possible pairwise reactions: 5
#
# target: BaZrS3
# reactants: ['ZrS', 'BaS2']
# reaction energy: -0.38214951699999206
# inverse hull energy: -0.13427631884999602
# reaction: ZrS + BaS2 -> BaZrS3
# competing phases: [['Zr3S4', 'BaS'], ['Ba3Zr2S7', 'Zr3S4']]
#
# target: BaZrS3
# reactants: ['Ba3Zr2S7', 'ZrS2']
# reaction energy: -0.018513945000180474
# inverse hull energy: -0.018513945000179888
# reaction: 0.3333 Ba3Zr2S7 + 0.3333 ZrS2 -> BaZrS3
# competing phases: []
#
# target: BaZrS3
# reactants: ['BaS', 'ZrS2']
# reaction energy: -0.06688641500001329
# inverse hull energy: -0.018513945000031562
# reaction: BaS + ZrS2 -> BaZrS3
# competing phases: ['Ba3Zr2S7']
#
#
# loading from cache. stable entries S-Sm-Yb
# Error processing YbSmS3: Yb1 Sm1 S3 has elements not in the phase diagram Sm, S
# loading from cache. stable entries Gd-S-Zr
# all possible pairwise reactions: 4
# No valid reactions found for GdZrS3. with the current reactions: [0.5 ZrS + 0.5 Gd2ZrS5 -> GdZrS3, ZrS + GdS2 -> GdZrS3, GdS + ZrS2 -> GdZrS3, Gd + ZrS3 -> GdZrS3]
# loading from cache. stable entries Eu-S-Y
# all possible pairwise reactions: 1
# No valid reactions found for EuYS3. with the current reactions: [YS + EuS2 -> EuYS3]
# loading from cache. stable entries Dy-In-S
# all possible pairwise reactions: 3
#
# target: DyInS3
# reactants: ['InS', 'DyS2']
# reaction energy: -0.10805064037499573
# inverse hull energy: -0.10805064037499612
# reaction: InS + DyS2 -> DyInS3
# competing phases: [['Dy2S3', 'In2S3']]
#
# target: DyInS3
# reactants: ['Dy2S3', 'In2S3']
# reaction energy: -0.00019999999999882327
# inverse hull energy: -0.0001999999999986457
# reaction: 0.5 Dy2S3 + 0.5 In2S3 -> DyInS3
# competing phases: []

# %% [markdown]
# Store the data for all reactions

# %%
import os
from tf_chpvk_pv.config import SYNTHESIS_DATA_DIR, PROCESSED_DATA_DIR

folder = str(SYNTHESIS_DATA_DIR / "results_files")

df_all = pd.DataFrame()

for composition in df_compositions.index:
    if not os.path.exists(f"{folder}/{composition}_result.csv"):
        print(f"File for {composition} does not exist, skipping.")
        continue
    df_rx = pd.read_csv(f"{folder}/{composition}_result.csv")
    if df_rx.empty:
        print(f"No reactions found for {composition}, skipping.")
        continue
    df_all = pd.concat([df_all, df_rx], ignore_index=True)

df_all.to_csv(PROCESSED_DATA_DIR / "results_synthesis_prediction.csv", index=False)
# Out:
# File for UCeSe3 does not exist, skipping.
# No reactions found for AlSnSe3, skipping.
# No reactions found for TbEuS3, skipping.
# File for YbEuSe3 does not exist, skipping.
# File for LuSmS3 does not exist, skipping.
# File for UPrSe3 does not exist, skipping.
# File for TbLaS3 does not exist, skipping.
# No reactions found for BaPrS3, skipping.
# No reactions found for EuScS3, skipping.
# No reactions found for SmZrS3, skipping.
# No reactions found for UBiS3, skipping.
# File for UScS3 does not exist, skipping.
# File for TbLaSe3 does not exist, skipping.
# File for UEuSe3 does not exist, skipping.
# File for TmEuS3 does not exist, skipping.
# File for YbEuS3 does not exist, skipping.
# No reactions found for DyZrS3, skipping.
# File for DyEuS3 does not exist, skipping.
# No reactions found for LaZrS3, skipping.
# File for UCeS3 does not exist, skipping.
# File for UEuS3 does not exist, skipping.
# No reactions found for ZrCuSe3, skipping.
# File for USmSe3 does not exist, skipping.
# File for YbSmS3 does not exist, skipping.
# No reactions found for GdZrS3, skipping.
# No reactions found for EuYS3, skipping.

# %% [markdown]
# Understand for which percentage of compounds we found thermodynamic data

# %%
from tf_chpvk_pv.config import PROCESSED_DATA_DIR

# Count compounds with data
compounds_with_data_no = df_all['target'].nunique() 
compounds_with_data = df_all['target'].unique()
total_compositions = len(df_compositions)

df_exp = pd.read_csv(PROCESSED_DATA_DIR / "chpvk_dataset.csv")
df_exp_label_1 = df_exp[df_exp['exp_label'] == 1]
df_exp_label_1SSe = df_exp_label_1[df_exp_label_1['X'].isin(['Se', 'S'])]

materials_reported_exp = [x for x in compounds_with_data if x in df_exp_label_1SSe['material'].values]

print(f"Compounds with synthesis data: {compounds_with_data_no}")
print(f"Compounds with synthesis data and reported experimentally: {len(materials_reported_exp)}")
print(f"Total compositions: {total_compositions}")
print(f"Total Coverage: {compounds_with_data_no/total_compositions*100:.1f}%")
print(f"Coverage of new compositions: {(compounds_with_data_no - len(materials_reported_exp))/total_compositions*100:.1f}%")
# Out:
# Compounds with synthesis data: 28
# Compounds with synthesis data and reported experimentally: 13
# Total compositions: 54
# Total Coverage: 51.9%
# Coverage of new compositions: 27.8%
