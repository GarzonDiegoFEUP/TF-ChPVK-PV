# %%
from synthesis_planning.synthesis_pathways import SynthesisPathways
from synthesis_planning.interfacial_pdplotter import InterReactions, Inter_PDPlotter

from pymatgen.analysis.reaction_calculator import ComputedReaction
from pymatgen.analysis.phase_diagram import CompoundPhaseDiagram

def get_reaction_from_string(target, to_show = True):

    # get the optimal synthesis recipe for a target material
    sp = SynthesisPathways(target,
                        exclude_reactants = ["O2"],
                        selected_reactions_to_csv = True)

    # display the selected reactions
    for reaction in sp.selected_reactions:
        reaction.display()

    # Visualize interfacial reaction compound phase diagram for the optimal reaction
    if len(sp.selected_reactions) > 0:
        reaction = sp.selected_reactions[0]
        interfacial_reactions = InterReactions(reaction)
        Inter_PDPlotter(
            interfacial_reactions,
            emphasize_entries = [reaction.target]
        ).show(to_show=to_show)

# %%
import pandas as pd

df_compositions = pd.read_csv('data/results CrystaLLM.csv')
df_compositions.rename(columns={'material': 'formula'}, inplace=True)
df_compositions.set_index('formula', inplace=True)


for formula in df_compositions.index:
    try:
        get_reaction_from_string(formula, False)
    except Exception as e:
        print(f"Error processing {formula}: {e}")
        continue

for formula in ['BaCu2Se2']:
    try:
        get_reaction_from_string(formula, True)
    except Exception as e:
        print(f"Error processing {formula}: {e}")
        raise
# Out:
# loading from cache. stable entries Se-Sr-U
# all possible pairwise reactions: 2
#
# target: SrUSe3
# reactants: ['SrSe', 'USe2']
# reaction energy: -0.00019999999999527067
# inverse hull energy: -0.000199999999995093
# reaction: SrSe + USe2 -> SrUSe3
# competing phases: []
# loading from cache. stable entries Ca-S-Zr
# all possible pairwise reactions: 2
#
# target: CaZrS3
# reactants: ['CaS', 'ZrS2']
# reaction energy: -0.00019999999998674415
# inverse hull energy: -0.00019999999998709939
# reaction: CaS + ZrS2 -> CaZrS3
# competing phases: []
# loading from cache. stable entries Ca-Ce-S
# all possible pairwise reactions: 1
#
# target: CaCeS3
# reactants: ['CeS2', 'CaS']
# reaction energy: -0.00019999999999811277
# inverse hull energy: -0.00019999999999775753
# reaction: CeS2 + CaS -> CaCeS3
# competing phases: []
# loading from cache. stable entries Eu-Hf-S
# all possible pairwise reactions: 3
#
# target: EuHfS3
# reactants: ['HfS', 'EuS2']
# reaction energy: -0.3733372305000006
# inverse hull energy: -0.22328404216663955
# reaction: HfS + EuS2 -> EuHfS3
# competing phases: [['Eu3S4', 'HfS3']]
#
# target: EuHfS3
# reactants: ['HfS2', 'EuS']
# reaction energy: -0.004473731499992086
# inverse hull energy: -0.0044737314999938604
# reaction: HfS2 + EuS -> EuHfS3
# competing phases: []
# loading from cache. stable entries Eu-S-Tb
# all possible pairwise reactions: 2
# No valid reactions found for TbEuS3. with the current reactions: [TbS2 + EuS -> TbEuS3, TbS + EuS2 -> TbEuS3]
# loading from cache. stable entries Pr-S-Sr
# all possible pairwise reactions: 2
#
# target: SrPrS3
# reactants: ['PrS2', 'SrS']
# reaction energy: -0.0001999999999988233
# inverse hull energy: -0.0001999999999986457
# reaction: PrS2 + SrS -> SrPrS3
# competing phases: []
# loading from cache. stable entries Ce-Se-U
# all possible pairwise reactions: 5
# No valid reactions found for CeUSe3. with the current reactions: [0.5 Ce2USe5 + 0.5 USe -> CeUSe3, CeSe2 + USe -> CeUSe3, Ce + USe3 -> CeUSe3, USe2 + CeSe -> CeUSe3, 0.5 U2Se3 + 0.5 Ce2Se3 -> CeUSe3]
# loading from cache. stable entries Ca-Hf-S
# all possible pairwise reactions: 2
#
# target: CaHfS3
# reactants: ['HfS2', 'CaS']
# reaction energy: -0.00020000000000095492
# inverse hull energy: -0.00020000000000042206
# reaction: HfS2 + CaS -> CaHfS3
# competing phases: []
# loading from cache. stable entries Eu-Gd-S
# all possible pairwise reactions: 3
#
# target: EuGdS3
# reactants: ['GdS2', 'EuS']
# reaction energy: -0.00732503470586323
# inverse hull energy: -0.00019999999997644125
# reaction: GdS2 + EuS -> EuGdS3
# competing phases: [['Eu3S4', 'Gd10S19'], ['Eu3S4', 'Eu(GdS2)2']]
# loading from cache. stable entries Eu-Se-Yb
# Error processing YbEuSe3: Yb1 Eu1 Se3 has elements not in the phase diagram Eu, Se
# loading from cache. stable entries S-Sr-U
# all possible pairwise reactions: 4
#
# target: SrUS3
# reactants: ['SrS', 'SrU2S5']
# reaction energy: -0.00020000000000237617
# inverse hull energy: -0.00020000000000219842
# reaction: 0.5 SrS + 0.5 SrU2S5 -> SrUS3
# competing phases: []
# loading from cache. stable entries In-S-U
# all possible pairwise reactions: 3
#
# target: UInS3
# reactants: ['In2S3', 'U2S3']
# reaction energy: -0.01495659937497606
# inverse hull energy: -0.00652537508329587
# reaction: 0.5 In2S3 + 0.5 U2S3 -> UInS3
# competing phases: [['US2', 'InS'], ['U3S5', 'InS']]
#
# target: UInS3
# reactants: ['US2', 'InS']
# reaction energy: -0.00020000000002227118
# inverse hull energy: -0.00020000000002085017
# reaction: US2 + InS -> UInS3
# competing phases: []
# loading from cache. stable entries Eu-S-U
# all possible pairwise reactions: 4
#
# target: EuUS3
# reactants: ['EuS2', 'US']
# reaction energy: -0.2986181749999985
# inverse hull energy: -0.024162808499989197
# reaction: EuS2 + US -> EuUS3
# competing phases: [['Eu3S4', 'US3'], ['US3', 'EuS'], ['US2', 'EuS'], ['U3S5', 'EuS'], ['U2S3', 'EuS']]
#
# target: EuUS3
# reactants: ['U3S5', 'Eu3S4']
# reaction energy: -0.04656069199999422
# inverse hull energy: -0.024162808499989197
# reaction: 0.3333 U3S5 + 0.3333 Eu3S4 -> EuUS3
# competing phases: [['US2', 'EuS'], ['US3', 'EuS']]
#
# target: EuUS3
# reactants: ['US2', 'EuS']
# reaction energy: -0.00020000000001800796
# inverse hull energy: -0.00020000000001729745
# reaction: US2 + EuS -> EuUS3
# competing phases: []
# loading from cache. stable entries In-Pr-S
# all possible pairwise reactions: 3
#
# target: PrInS3
# reactants: ['PrS2', 'InS']
# reaction energy: -0.05473922787500099
# inverse hull energy: -0.041622509400005114
# reaction: PrS2 + InS -> PrInS3
# competing phases: [['Pr10S19', 'In2S3'], ['Pr2S3', 'In2S3']]
#
# target: PrInS3
# reactants: ['In2S3', 'Pr2S3']
# reaction energy: -0.0001999999999810597
# inverse hull energy: -0.00019999999998088214
# reaction: 0.5 In2S3 + 0.5 Pr2S3 -> PrInS3
# competing phases: []
# loading from cache. stable entries Eu-S-Sc
# all possible pairwise reactions: 1
# No valid reactions found for EuScS3. with the current reactions: [EuS2 + ScS -> EuScS3]
# loading from cache. stable entries Ce-S-Y
# all possible pairwise reactions: 3
#
# target: CeYS3
# reactants: ['CeS2', 'YS']
# reaction energy: -0.22388275016666334
# inverse hull energy: -0.05855781883333133
# reaction: CeS2 + YS -> CeYS3
# competing phases: [['Ce(YS2)3', 'Ce2S3'], ['Ce(YS2)3', 'CeS'], ['Y2S3', 'CeS'], ['Y5S7', 'CeS']]
#
# target: CeYS3
# reactants: ['Ce(YS2)3', 'Ce2S3']
# reaction energy: -0.00019999999996116443
# inverse hull energy: -0.00019999999995956586
# reaction: 0.3333 Ce(YS2)3 + 0.3333 Ce2S3 -> CeYS3
# competing phases: []
# loading from cache. stable entries La-S-Tl
# all possible pairwise reactions: 1
# No valid reactions found for LaTlS3. with the current reactions: [3 S + LaTl -> LaTlS3]
# loading from cache. stable entries In-S-Tb
# all possible pairwise reactions: 2
#
# target: TbInS3
# reactants: ['InS', 'TbS2']
# reaction energy: -0.07082171512500181
# inverse hull energy: -0.07082171512500146
# reaction: InS + TbS2 -> TbInS3
# competing phases: [['Tb2S3', 'In2S3']]
#
# target: TbInS3
# reactants: ['In2S3', 'Tb2S3']
# reaction energy: -0.00019999999998034917
# inverse hull energy: -0.00019999999998088214
# reaction: 0.5 In2S3 + 0.5 Tb2S3 -> TbInS3
# competing phases: []
# loading from cache. stable entries Ba-Pr-S
# all possible pairwise reactions: 3
# No valid reactions found for BaPrS3. with the current reactions: [BaS3 + Pr -> BaPrS3, PrS2 + BaS -> BaPrS3, BaS2 + PrS -> BaPrS3]
# loading from cache. stable entries Ce-S-Sc
# all possible pairwise reactions: 2
#
# target: CeScS3
# reactants: ['ScS', 'CeS2']
# reaction energy: -0.1943157570000053
# inverse hull energy: -0.09257641600000266
# reaction: ScS + CeS2 -> CeScS3
# competing phases: [['Sc2S3', 'CeS']]
#
# target: CeScS3
# reactants: ['Sc2S3', 'Ce2S3']
# reaction energy: -0.005039687750006311
# inverse hull energy: -0.005039687750005406
# reaction: 0.5 Sc2S3 + 0.5 Ce2S3 -> CeScS3
# competing phases: []
# loading from cache. stable entries Eu-S-Tm
# all possible pairwise reactions: 1
# No valid reactions found for EuTmS3. with the current reactions: [TmS + EuS2 -> EuTmS3]
# loading from cache. stable entries In-La-S
# all possible pairwise reactions: 4
#
# target: LaInS3
# reactants: ['LaS2', 'InS']
# reaction energy: -0.054188107416668865
# inverse hull energy: -0.05418810741666835
# reaction: LaS2 + InS -> LaInS3
# competing phases: [['La3InS6', 'In2S3']]
#
# target: LaInS3
# reactants: ['In2S3', 'La3InS6']
# reaction energy: -0.0002000000000030864
# inverse hull energy: -0.0002000000000030866
# reaction: 0.3333 In2S3 + 0.3333 La3InS6 -> LaInS3
# competing phases: []
# loading from cache. stable entries Eu-Se-U
# all possible pairwise reactions: 3
#
# target: EuUSe3
# reactants: ['EuSe', 'USe2']
# reaction energy: -0.00019999999999669176
# inverse hull energy: -0.00019999999999598117
# reaction: EuSe + USe2 -> EuUSe3
# competing phases: []
# loading from cache. stable entries Ba-S-Sn
# all possible pairwise reactions: 11
#
# target: BaSnS3
# reactants: ['BaS2', 'SnS']
# reaction energy: -0.08347072161110841
# inverse hull energy: -0.035919427611111665
# reaction: BaS2 + SnS -> BaSnS3
# competing phases: [['Ba2SnS4', 'BaS3'], ['Ba3Sn2S7', 'BaS3'], ['Ba6Sn7S20', 'Ba3Sn2S7']]
#
# target: BaSnS3
# reactants: ['BaSn2S3', 'BaS3']
# reaction energy: -0.08120666561111492
# inverse hull energy: -0.03591942761103706
# reaction: 0.5 BaSn2S3 + 0.5 BaS3 -> BaSnS3
# competing phases: [['Ba8Sn4S15', 'SnS'], ['Ba2SnS4', 'SnS'], ['Ba3Sn2S7', 'SnS'], ['Ba6Sn7S20', 'Ba3Sn2S7']]
#
# target: BaSnS3
# reactants: ['Ba3Sn2S7', 'Ba6Sn7S20']
# reaction energy: -0.0001999999998247401
# inverse hull energy: -0.00019999999982456274
# reaction: 0.1111 Ba3Sn2S7 + 0.1111 Ba6Sn7S20 -> BaSnS3
# competing phases: []
# loading from cache. stable entries Se-Sm-Tb
# all possible pairwise reactions: 1
#
# target: TbSmSe3
# reactants: ['Tb2Se3', 'Sm2Se3']
# reaction energy: -0.00019999999999811285
# inverse hull energy: -0.00019999999999953388
# reaction: 0.5 Tb2Se3 + 0.5 Sm2Se3 -> TbSmSe3
# competing phases: []
# loading from cache. stable entries Pr-S-Zr
# all possible pairwise reactions: 4
# No valid reactions found for PrZrS3. with the current reactions: [0.5 ZrS + 0.5 Pr2ZrS5 -> PrZrS3, ZrS + PrS2 -> PrZrS3, ZrS2 + PrS -> PrZrS3, ZrS3 + Pr -> PrZrS3]
# loading from cache. stable entries Ba-S-Zr
# all possible pairwise reactions: 5
#
# target: BaZrS3
# reactants: ['ZrS', 'BaS2']
# reaction energy: -0.38214951699999206
# inverse hull energy: -0.1342763188499969
# reaction: ZrS + BaS2 -> BaZrS3
# competing phases: [['Zr3S4', 'BaS'], ['Ba3Zr2S7', 'Zr3S4']]
#
# target: BaZrS3
# reactants: ['Ba3Zr2S7', 'ZrS2']
# reaction energy: -0.018513945000181664
# inverse hull energy: -0.018513945000181664
# reaction: 0.3333 Ba3Zr2S7 + 0.3333 ZrS2 -> BaZrS3
# competing phases: []
#
# target: BaZrS3
# reactants: ['BaS', 'ZrS2']
# reaction energy: -0.06688641500000901
# inverse hull energy: -0.018513945000031562
# reaction: BaS + ZrS2 -> BaZrS3
# competing phases: ['Ba3Zr2S7']
# loading from cache. stable entries S-Sc-Tb
# all possible pairwise reactions: 2
#
# target: TbScS3
# reactants: ['TbS2', 'ScS']
# reaction energy: -0.2100996034999894
# inverse hull energy: -0.047167852249982545
# reaction: TbS2 + ScS -> TbScS3
# competing phases: [['Tb2S3', 'Sc2S3'], ['Tb3Sc2S7', 'Sc2S3']]
#
# target: TbScS3
# reactants: ['Sc2S3', 'Tb2S3']
# reaction energy: -0.00019999999997537537
# inverse hull energy: -0.00019999999997644125
# reaction: 0.5 Sc2S3 + 0.5 Tb2S3 -> TbScS3
# competing phases: []
# loading from cache. stable entries Eu-S-Y
# all possible pairwise reactions: 1
# No valid reactions found for EuYS3. with the current reactions: [YS + EuS2 -> EuYS3]
# loading from cache. stable entries Ba-S-U
# all possible pairwise reactions: 6
#
# target: BaUS3
# reactants: ['BaS2', 'US']
# reaction energy: -0.3209084235000008
# inverse hull energy: -0.11134184909999956
# reaction: BaS2 + US -> BaUS3
# competing phases: [['Ba2US6', 'BaS'], ['U2S3', 'BaS']]
#
# target: BaUS3
# reactants: ['BaS', 'BaU2S5']
# reaction energy: -0.020905155500000227
# inverse hull energy: -0.02090515550000216
# reaction: 0.5 BaS + 0.5 BaU2S5 -> BaUS3
# competing phases: []
#
# target: BaUS3
# reactants: ['US2', 'BaS']
# reaction energy: -0.06733892749997003
# inverse hull energy: -0.020905155499671757
# reaction: US2 + BaS -> BaUS3
# competing phases: ['BaU2S5']
# loading from cache. stable entries Gd-S-Sc
# all possible pairwise reactions: 3
#
# target: GdScS3
# reactants: ['GdS2', 'ScS']
# reaction energy: -0.20901087583332434
# inverse hull energy: -0.041181213671576344
# reaction: GdS2 + ScS -> GdScS3
# competing phases: [['Gd10S19', 'Sc2S3'], ['Gd3ScS6', 'Sc2S3'], ['Gd3Sc2S7', 'Sc2S3']]
#
# target: GdScS3
# reactants: ['Sc2S3', 'Gd3ScS6']
# reaction energy: -0.00019999999999384936
# inverse hull energy: -0.0001999999999942048
# reaction: 0.3333 Sc2S3 + 0.3333 Gd3ScS6 -> GdScS3
# competing phases: []
# loading from cache. stable entries La-S-Tb
# all possible pairwise reactions: 3
#
# target: LaTbS3
# reactants: ['LaS2', 'TbS']
# reaction energy: -0.21307448125003667
# inverse hull energy: -0.03678303114292625
# reaction: LaS2 + TbS -> LaTbS3
# competing phases: [['La10S19', 'Tb2S3'], ['La2S3', 'Tb2S3'], ['La2S3', 'Tb5S7'], ['Tb5S7', 'LaS']]
#
# target: LaTbS3
# reactants: ['TbS2', 'LaS']
# reaction energy: -0.23191338675003972
# inverse hull energy: -0.026691160482757326
# reaction: TbS2 + LaS -> LaTbS3
# competing phases: [['LaS2', 'Tb2S3'], ['La10S19', 'Tb2S3'], ['La2S3', 'Tb2S3'], ['La2S3', 'Tb5S7']]
#
# target: LaTbS3
# reactants: ['Tb2S3', 'La2S3']
# reaction energy: -0.00019999999995832233
# inverse hull energy: -0.0001999999999577895
# reaction: 0.5 Tb2S3 + 0.5 La2S3 -> LaTbS3
# competing phases: []
# loading from cache. stable entries Eu-S-Zr
# all possible pairwise reactions: 3
#
# target: EuZrS3
# reactants: ['EuS2', 'ZrS']
# reaction energy: -0.3765158570000179
# inverse hull energy: -0.029000691386379174
# reaction: EuS2 + ZrS -> EuZrS3
# competing phases: [['Eu3S4', 'ZrS3'], ['Eu5(ZrS4)3', 'ZrS3'], ['Eu5(ZrS4)3', 'ZrS2'], ['Zr3S4', 'EuS']]
#
# target: EuZrS3
# reactants: ['EuS', 'ZrS2']
# reaction energy: -0.016404076000017653
# inverse hull energy: -0.016404076000016587
# reaction: EuS + ZrS2 -> EuZrS3
# competing phases: []
# loading from cache. stable entries S-Sc-U
# all possible pairwise reactions: 4
#
# target: ScUS3
# reactants: ['ScS', 'US2']
# reaction energy: -0.12472128900006967
# inverse hull energy: -0.023477991750159966
# reaction: ScS + US2 -> ScUS3
# competing phases: [['Sc2S3', 'US'], ['Sc2S3', 'U2S3'], ['U3S5', 'Sc2S3'], 'ScU8S17']
#
# target: ScUS3
# reactants: ['ScS', 'ScU8S17']
# reaction energy: -0.10111675999995094
# inverse hull energy: -0.023477991749978777
# reaction: 0.875 ScS + 0.125 ScU8S17 -> ScUS3
# competing phases: [['Sc2S3', 'US'], ['Sc2S3', 'U2S3'], ['U3S5', 'Sc2S3']]
#
# target: ScUS3
# reactants: ['Sc2S3', 'U2S3']
# reaction energy: -0.00019999999999811285
# inverse hull energy: -0.00019999999999775753
# reaction: 0.5 Sc2S3 + 0.5 U2S3 -> ScUS3
# competing phases: []
# loading from cache. stable entries Ba-Ce-S
# all possible pairwise reactions: 3
#
# target: BaCeS3
# reactants: ['BaS', 'CeS2']
# reaction energy: -0.00020000000001019205
# inverse hull energy: -0.00020000000000930385
# reaction: BaS + CeS2 -> BaCeS3
# competing phases: []
# loading from cache. stable entries Ce-S-Yb
# Error processing YbCeS3: Yb1 Ce1 S3 has elements not in the phase diagram Ce, S
# loading from cache. stable entries La-S-Sc
# all possible pairwise reactions: 2
#
# target: LaScS3
# reactants: ['LaS2', 'ScS']
# reaction energy: -0.21281249799998347
# inverse hull energy: -0.21281249799998392
# reaction: LaS2 + ScS -> LaScS3
# competing phases: []
#
# target: LaScS3
# reactants: ['Sc2S3', 'La2S3']
# reaction energy: -0.025083054250006932
# inverse hull energy: -0.025083054250005787
# reaction: 0.5 Sc2S3 + 0.5 La2S3 -> LaScS3
# competing phases: []
# loading from cache. stable entries S-Sm-Zr
# all possible pairwise reactions: 4
# No valid reactions found for SmZrS3. with the current reactions: [SmS2 + ZrS -> SmZrS3, ZrS3 + Sm -> SmZrS3, SmS + ZrS2 -> SmZrS3, 0.5 Sm2ZrS5 + 0.5 ZrS -> SmZrS3]
# loading from cache. stable entries Eu-Pr-S
# all possible pairwise reactions: 3
# No valid reactions found for PrEuS3. with the current reactions: [0.5 Pr2EuS4 + 0.5 EuS2 -> PrEuS3, EuS2 + PrS -> PrEuS3, PrS2 + EuS -> PrEuS3]
# loading from cache. stable entries Eu-S-Yb
# Error processing YbEuS3: Yb1 Eu1 S3 has elements not in the phase diagram Eu, S
# loading from cache. stable entries S-Sm-Yb
# Error processing YbSmS3: Yb1 Sm1 S3 has elements not in the phase diagram Sm, S
# loading from cache. stable entries Se-Sm-Y
# all possible pairwise reactions: 3
#
# target: SmYSe3
# reactants: ['YSe2', 'SmSe']
# reaction energy: -0.23376119824998862
# inverse hull energy: -0.08508411258337567
# reaction: YSe2 + SmSe -> SmYSe3
# competing phases: [['Sm10Se19', 'Y2Se3'], ['Sm2Se3', 'Y2Se3']]
#
# target: SmYSe3
# reactants: ['Y2Se3', 'Sm2Se3']
# reaction energy: -0.0001999999999810597
# inverse hull energy: -0.00019999999998177032
# reaction: 0.5 Y2Se3 + 0.5 Sm2Se3 -> SmYSe3
# competing phases: []
# loading from cache. stable entries Ce-In-S
# all possible pairwise reactions: 2
#
# target: CeInS3
# reactants: ['CeS2', 'InS']
# reaction energy: -0.05019818087499884
# inverse hull energy: -0.05019818087499761
# reaction: CeS2 + InS -> CeInS3
# competing phases: [['Ce2S3', 'In2S3']]
#
# target: CeInS3
# reactants: ['In2S3', 'Ce2S3']
# reaction energy: -0.0001999999999796386
# inverse hull energy: -0.00019999999997910578
# reaction: 0.5 In2S3 + 0.5 Ce2S3 -> CeInS3
# competing phases: []
# loading from cache. stable entries Lu-S-Sm
# all possible pairwise reactions: 2
#
# target: SmLuS3
# reactants: ['LuS', 'SmS2']
# reaction energy: -0.266036186250001
# inverse hull energy: -0.09361626474999163
# reaction: LuS + SmS2 -> SmLuS3
# competing phases: [['Lu3S4', 'SmS'], ['Lu2S3', 'SmS'], ['Sm2S3', 'Lu2S3'], ['Sm10S19', 'Lu2S3']]
#
# target: SmLuS3
# reactants: ['Lu2S3', 'Sm2S3']
# reaction energy: -0.00019999999997395428
# inverse hull energy: -0.0001999999999737767
# reaction: 0.5 Lu2S3 + 0.5 Sm2S3 -> SmLuS3
# competing phases: []
# loading from cache. stable entries Cd-S-U
# all possible pairwise reactions: 3
#
# target: UCdS3
# reactants: ['CdS2', 'US']
# reaction energy: -0.33174311799999423
# inverse hull energy: -0.024162808500014066
# reaction: CdS2 + US -> UCdS3
# competing phases: [['US3', 'CdS'], ['US2', 'CdS'], ['U3S5', 'CdS'], ['U2S3', 'CdS'], ['U2S3', 'Cd']]
#
# target: UCdS3
# reactants: ['CdS', 'US2']
# reaction energy: -0.00020000000000450763
# inverse hull energy: -0.00020000000000486295
# reaction: CdS + US2 -> UCdS3
# competing phases: []
# loading from cache. stable entries S-Sr-Zr
# all possible pairwise reactions: 3
#
# target: SrZrS3
# reactants: ['ZrS2', 'SrS']
# reaction energy: -0.01155678599999843
# inverse hull energy: -0.011556785999998098
# reaction: ZrS2 + SrS -> SrZrS3
# competing phases: []
# loading from cache. stable entries Er-Eu-S
# all possible pairwise reactions: 3
#
# target: EuErS3
# reactants: ['Eu(ErS2)2', 'EuS2']
# reaction energy: -0.00019999999999242857
# inverse hull energy: -0.00019999999999331664
# reaction: 0.5 Eu(ErS2)2 + 0.5 EuS2 -> EuErS3
# competing phases: []
# loading from cache. stable entries S-Sc-Sm
# all possible pairwise reactions: 2
#
# target: SmScS3
# reactants: ['ScS', 'SmS2']
# reaction energy: -0.2075815115000361
# inverse hull energy: -0.16405940025001264
# reaction: ScS + SmS2 -> SmScS3
# competing phases: [['Sm10S19', 'Sc2S3']]
#
# target: SmScS3
# reactants: ['Sc2S3', 'Sm2S3']
# reaction energy: -0.0074254105000051375
# inverse hull energy: -0.007425410500005114
# reaction: 0.5 Sc2S3 + 0.5 Sm2S3 -> SmScS3
# competing phases: []
# loading from cache. stable entries Eu-Ho-S
# all possible pairwise reactions: 3
#
# target: EuHoS3
# reactants: ['Eu(HoS2)2', 'EuS2']
# reaction energy: -0.00019999999998958638
# inverse hull energy: -0.00019999999998976392
# reaction: 0.5 Eu(HoS2)2 + 0.5 EuS2 -> EuHoS3
# competing phases: []
# loading from cache. stable entries Dy-S-Sc
# all possible pairwise reactions: 2
#
# target: DyScS3
# reactants: ['ScS', 'DyS2']
# reaction energy: -0.2473285287499976
# inverse hull energy: -0.053898092375005646
# reaction: ScS + DyS2 -> DyScS3
# competing phases: [['Dy3Sc2S7', 'Sc2S3'], ['Dy2S3', 'Sc2S3']]
#
# target: DyScS3
# reactants: ['Sc2S3', 'Dy2S3']
# reaction energy: -0.00019999999997537537
# inverse hull energy: -0.00019999999997732942
# reaction: 0.5 Sc2S3 + 0.5 Dy2S3 -> DyScS3
# competing phases: []
# loading from cache. stable entries Ba-Se-U
# all possible pairwise reactions: 7
#
# target: BaUSe3
# reactants: ['BaSe2', 'USe']
# reaction energy: -0.30184914235714033
# inverse hull energy: -0.05078818585714995
# reaction: BaSe2 + USe -> BaUSe3
# competing phases: [['USe3', 'Ba4USe6'], ['BaU2Se5', 'Ba4USe6'], ['Ba4USe6', 'U2Se3'], ['U2Se3', 'BaSe']]
#
# target: BaUSe3
# reactants: ['BaU2Se5', 'Ba4USe6']
# reaction energy: -0.00019999999998958644
# inverse hull energy: -0.00019999999998976392
# reaction: 0.4286 BaU2Se5 + 0.1429 Ba4USe6 -> BaUSe3
# competing phases: []
# loading from cache. stable entries Se-Sm-U
# all possible pairwise reactions: 3
#
# target: SmUSe3
# reactants: ['USe2', 'SmSe']
# reaction energy: -0.12647481064997804
# inverse hull energy: -0.03261866938887614
# reaction: USe2 + SmSe -> SmUSe3
# competing phases: [['Sm2Se3', 'U11Se20'], ['Sm2Se3', 'U2Se3'], ['USe', 'Sm2Se3'], ['Sm2Se3', 'U']]
#
# target: SmUSe3
# reactants: ['Sm2Se3', 'U2Se3']
# reaction energy: -0.00019999999999669176
# inverse hull energy: -0.00019999999999686935
# reaction: 0.5 Sm2Se3 + 0.5 U2Se3 -> SmUSe3
# competing phases: []
# loading from cache. stable entries Pr-S-Sc
# all possible pairwise reactions: 2
#
# target: PrScS3
# reactants: ['PrS2', 'ScS']
# reaction energy: -0.21174294299998833
# inverse hull energy: -0.21174294299998753
# reaction: PrS2 + ScS -> PrScS3
# competing phases: []
#
# target: PrScS3
# reactants: ['Sc2S3', 'Pr2S3']
# reaction energy: -0.01792582675000608
# inverse hull energy: -0.017925826750005314
# reaction: 0.5 Sc2S3 + 0.5 Pr2S3 -> PrScS3
# competing phases: []
# loading from cache. stable entries Cd-S-Zr
# all possible pairwise reactions: 3
#
# target: ZrCdS3
# reactants: ['ZrS3', 'Cd']
# reaction energy: -0.20274477099998692
# inverse hull energy: -0.20274477099998656
# reaction: ZrS3 + Cd -> ZrCdS3
# competing phases: [['ZrS2', 'CdS']]
#
# target: ZrCdS3
# reactants: ['ZrS', 'CdS2']
# reaction energy: -0.3934367240000036
# inverse hull energy: -0.06771492366667609
# reaction: ZrS + CdS2 -> ZrCdS3
# competing phases: [['Zr3S4', 'Cd'], ['ZrS2', 'Cd'], ['ZrS2', 'CdS'], ['ZrS3', 'CdS']]
#
# target: ZrCdS3
# reactants: ['CdS', 'ZrS2']
# reaction energy: -0.00019999999999456005
# inverse hull energy: -0.00019999999999331664
# reaction: CdS + ZrS2 -> ZrCdS3
# competing phases: []
# loading from cache. stable entries Ca-S-U
# all possible pairwise reactions: 2
#
# target: CaUS3
# reactants: ['CaS', 'US2']
# reaction energy: -0.0001999999999995339
# inverse hull energy: -0.00019999999999953388
# reaction: CaS + US2 -> CaUS3
# competing phases: []
# loading from cache. stable entries Dy-Eu-S
# all possible pairwise reactions: 3
#
# target: EuDyS3
# reactants: ['Eu(DyS2)2', 'EuS2']
# reaction energy: -0.00019999999998958638
# inverse hull energy: -0.0001999999999906521
# reaction: 0.5 Eu(DyS2)2 + 0.5 EuS2 -> EuDyS3
# competing phases: []
# loading from cache. stable entries Cd-Ce-S
# all possible pairwise reactions: 2
#
# target: CeCdS3
# reactants: ['CdS', 'CeS2']
# reaction energy: -0.00020000000000806035
# inverse hull energy: -0.0002000000000075275
# reaction: CdS + CeS2 -> CeCdS3
# competing phases: []
# loading from cache. stable entries Eu-Lu-S
# all possible pairwise reactions: 1
# No valid reactions found for EuLuS3. with the current reactions: [LuS + EuS2 -> EuLuS3]
# loading from cache. stable entries Ba-Cu-Se
# all possible pairwise reactions: 3
# No valid reactions found for Ba(CuSe)2. with the current reactions: [2 Cu + BaSe2 -> Ba(CuSe)2, Ba + 2 CuSe -> Ba(CuSe)2, CuSe2 + BaCu -> Ba(CuSe)2]

# %%
import os

folder = os.getcwd() + "/data/results_files"

df_all = pd.DataFrame()

for composition in df_compositions.index:
    if not os.path.exists(f"{folder}/{composition}_result.csv"):
        print(f"File for {composition} does not exist, skipping.")
        continue
    df_rx = pd.read_csv(f"{folder}/{composition}_result.csv")
    if df_rx.empty:
        print(f"No reactions found for {composition}, skipping.")
        continue
    df_all = pd.concat([df_all, df_rx], ignore_index=True)

df_all.to_csv(f"{folder}/00_all_results.csv", index=False)
# Out:
# No reactions found for TbEuS3, skipping.
# No reactions found for CeUSe3, skipping.
# File for YbEuSe3 does not exist, skipping.
# No reactions found for EuScS3, skipping.
# No reactions found for LaTlS3, skipping.
# No reactions found for BaPrS3, skipping.
# No reactions found for EuTmS3, skipping.
# No reactions found for PrZrS3, skipping.
# No reactions found for EuYS3, skipping.
# File for YbCeS3 does not exist, skipping.
# No reactions found for SmZrS3, skipping.
# No reactions found for PrEuS3, skipping.
# File for YbEuS3 does not exist, skipping.
# File for YbSmS3 does not exist, skipping.
# No reactions found for EuLuS3, skipping.
